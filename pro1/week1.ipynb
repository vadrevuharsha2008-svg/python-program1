# %% [markdown]
# <a href="https://colab.research.google.com/github/vadrevuharsha2008-svg/python-program1/blob/main/pro1/week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
a=11
print(type(a))
# Out:
# <class 'int'>

# %%
b=12.88
print(type(b))
# Out:
# <class 'float'>

# %%
print(1+4*3)
# Out:
# 13

# %%
print("1=4")
# Out:
# 1=4

# %%
a=float(input("enter number"))
b=float(input("enter number"))
print(a+b)
print(a*b)
print(a/b)
print(a//b)
print(a-b)
# Out:
# enter number5
# enter number3
# 8.0
# 15.0
# 1.6666666666666667
# 1.0
# 2.0
